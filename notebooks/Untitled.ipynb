# %%
pwd
# Out:
# '/home/appuser/data/Pytorch-UNet/notebooks'

# %%
cd /home/appuser/data/TopoLoss/Data
# Out:
# /home/appuser/data/TopoLoss/Data

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.load("20_1.npy")

# %%
plt.imshow(x)
